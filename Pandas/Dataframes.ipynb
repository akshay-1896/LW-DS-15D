# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Clever'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3  Clever   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Clever', 42, 'London', 85000]
]
data_list
# Out:
# [['John', 28, 'New York', 65000],
#  ['Anna', 34, 'Paris', 70000],
#  ['Peter', 29, 'Berlin', 62000],
#  ['Clever', 42, 'London', 85000]]

# %%
df2 = pd.DataFrame(data_list)
cols = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=cols)
df2
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3  Clever   42    London   85000

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3  Clever   42    London   85000

# %%
df2['Name']
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[['Name','City']] # To get multiple columns, we provide list of columns
# Out:
#      Name      City
# 0    John  New York
# 1    Anna     Paris
# 2   Peter    Berlin
# 3  Clever    London

# %% [markdown]
# Creating a New Column

# %%
df2['Designation'] = ['Doctor', 'ML Engineer', 'Teacher', 'Doctor']

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3  Clever   42    London   85000

# %% [markdown]
# Removing a Column

# %%
df2
# Out:
#      Name  Age      City  Salary  Designation
# 0    John   28  New York   65000       Doctor
# 1    Anna   34     Paris   70000  ML Engineer
# 2   Peter   29    Berlin   62000      Teacher
# 3  Clever   42    London   85000       Doctor

# %%
df2.drop(0, axis=0)
# Out:
#      Name  Age    City  Salary  Designation
# 1    Anna   34   Paris   70000  ML Engineer
# 2   Peter   29  Berlin   62000      Teacher
# 3  Clever   42  London   85000       Doctor

# %%
df2.drop(['City','Salary'], axis=1)
# Out:
#      Name  Age  Designation
# 0    John   28       Doctor
# 1    Anna   34  ML Engineer
# 2   Peter   29      Teacher
# 3  Clever   42       Doctor

# %%
df2.drop(0)
# Out:
#      Name  Age    City  Salary  Designation
# 1    Anna   34   Paris   70000  ML Engineer
# 2   Peter   29  Berlin   62000      Teacher
# 3  Clever   42  London   85000       Doctor

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#      Name  Age      City  Salary  Designation
# 0    John   28  New York   65000       Doctor
# 1    Anna   34     Paris   70000  ML Engineer
# 2   Peter   29    Berlin   62000      Teacher
# 3  Clever   42    London   85000       Doctor

# %%
# df2[0] # Throws Keyerror
df2.loc[[0,1]] # label-based location access
# Out:
#    Name  Age      City  Salary  Designation
# 0  John   28  New York   65000       Doctor
# 1  Anna   34     Paris   70000  ML Engineer

# %%
df3 = df2.copy() # Deep copy
df3.index = ['A','B','C','D']
df3
# Out:
#      Name  Age      City  Salary  Designation
# A    John   28  New York   65000       Doctor
# B    Anna   34     Paris   70000  ML Engineer
# C   Peter   29    Berlin   62000      Teacher
# D  Clever   42    London   85000       Doctor

# %%
df3.loc['B'] # Label based
# Out:
# Name                  Anna
# Age                     34
# City                 Paris
# Salary               70000
# Designation    ML Engineer
# Name: B, dtype: object

# %%
df3.iloc[1] # Integer Based
# Out:
# Name                  Anna
# Age                     34
# City                 Paris
# Salary               70000
# Designation    ML Engineer
# Name: B, dtype: object

# %%
df2
# Out:
#      Name  Age      City  Salary  Designation
# 0    John   28  New York   65000       Doctor
# 1    Anna   34     Paris   70000  ML Engineer
# 2   Peter   29    Berlin   62000      Teacher
# 3  Clever   42    London   85000       Doctor

# %%
df2.loc[[1,2]][['Name','Salary']]
# Out:
#     Name  Salary
# 1   Anna   70000
# 2  Peter   62000

# %%
df2.loc[[1,2], ['Name', 'Salary']]
# Out:
#     Name  Salary
# 1   Anna   70000
# 2  Peter   62000

# %% [markdown]
# Conditional Selection

# %%
df2
# Out:
#      Name  Age      City  Salary  Designation
# 0    John   28  New York   65000       Doctor
# 1    Anna   34     Paris   70000  ML Engineer
# 2   Peter   29    Berlin   62000      Teacher
# 3  Clever   42    London   85000       Doctor

# %%
# People with age > 30

df2[df2['Age'] > 30]
# Out:
#      Name  Age    City  Salary  Designation
# 1    Anna   34   Paris   70000  ML Engineer
# 3  Clever   42  London   85000       Doctor

# %%
df2
# Out:
#      Name  Age      City  Salary  Designation
# 0    John   28  New York   65000       Doctor
# 1    Anna   34     Paris   70000  ML Engineer
# 2   Peter   29    Berlin   62000      Teacher
# 3  Clever   42    London   85000       Doctor

# %%
# People with age > 30 & Salary > 70000

df2[(df2['Age'] > 30) & (df2['Salary'] > 70000)]
# Out:
#      Name  Age    City  Salary Designation
# 3  Clever   42  London   85000      Doctor

# %%
df2[(df2['Age'] > 30) & (df2['City'] == 'London')]
# Out:
#      Name  Age    City  Salary Designation
# 3  Clever   42  London   85000      Doctor
