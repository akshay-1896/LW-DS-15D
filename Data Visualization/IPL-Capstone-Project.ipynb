# %% [markdown]
# ## **IPL 2022 Capstone Project**
#
# The Indian Premier League (IPL) is a professional T20 cricket league in India, featuring franchises representing cities. This project explores IPL 2022 match-level data to derive meaningful insights and understand match outcomes, player performances, and team dynamics.
#
# These are some of the important columns that we'll focus on for meaningful insights in this project.
#
# column names: Variable Type
#
# - date : string
# - venue : string
# - stage : string
# - team1 : string
# - team2 : string
# - toss_winner : string
# - toss_decision : string
# - first_ings_score : integer
# - second_ings_score : integer
# - match_winner : string
# - won_by : string
# - margin : integer
# - player_of_the_match : string
# - top_scorer : string
# - highscore : integer
# - best_bowling : string
# - best_bowling_fgure : string
# - gure : string

# %%
import plotly.offline as iplot
import plotly.express as px

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('IPL.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# ## Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.describe()
df.shape
# Out:
# (74, 20)

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
df.nlargest(1,"first_ings_score")
# Out:
#     match_id           date                     venue  team1      team2  \
# 33        34  April 22,2022  Wankhede Stadium, Mumbai  Delhi  Rajasthan
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 33  Group       Delhi         Field               222                2
#
#     second_ings_score  second_ings_wkts match_winner won_by  margin  \
# 33                207                 8    Rajasthan   Runs      15
#
#    player_of_the_match   top_scorer  highscore     best_bowling  \
# 33         Jos Buttler  Jos Buttler        116  Prasidh Krishna
#
#    best_bowling_figure
# 33               3--22

# %%
df.sort_values(by='second_ings_score',ascending=False)[['team1','team2','second_ings_score']]
# Out:
#        team1      team2  second_ings_score
# 6    Chennai    Lucknow                211
# 29   Kolkata  Rajasthan                210
# 65   Kolkata    Lucknow                208
# 2   Banglore     Punjab                208
# 33     Delhi  Rajasthan                207
# ..       ...        ...                ...
# 55   Kolkata     Mumbai                113
# 58   Chennai     Mumbai                103
# 52   Kolkata    Lucknow                101
# 56   Lucknow    Gujarat                 82
# 35  Banglore  Hyderabad                 72
#
# [74 rows x 3 columns]

# %%
df[df['match_winner'] == 'Chennai'].value_counts().count()
# Out:
# np.int64(4)

# %% [markdown]
# ## **Some Basic Questions**

# %%
match_wins = df['match_winner'].value_counts()
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Punjab        7
# Delhi         7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
match_wins.values
match_wins.index
# Out:
# Index(['Gujarat', 'Rajasthan', 'Banglore', 'Lucknow', 'Punjab', 'Delhi',
#        'Kolkata', 'Hyderabad', 'Chennai', 'Mumbai'],
#       dtype='object', name='match_winner')

# %%
sns.barplot(x = match_wins.values, y = match_wins.index, palette='coolwarm',)
# Out:
# <Axes: ylabel='match_winner'>

# %%
px.bar(x = match_wins.values, y = match_wins.index,title='Most Matching Winning Teams')

# %%
px.line(df['match_winner'].value_counts())

# %%
px.line(match_wins)

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
sns.barplot(data = df, x='toss_winner', hue='toss_decision')
# Out:
# <Axes: xlabel='toss_winner'>

# %%
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Hyderabad    10
# Gujarat      10
# Mumbai        9
# Kolkata       8
# Delhi         8
# Banglore      8
# Lucknow       7
# Chennai       6
# Punjab        4
# Rajasthan     4
# Name: count, dtype: int64

# %%
sns.countplot(y=df['toss_winner'],hue=df['toss_decision'],palette='viridis',color=df['match_winner'])
# Out:
# <Axes: xlabel='count', ylabel='toss_winner'>

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
count = df[df['toss_winner'] == df['match_winner']]['match_id'].count()
percentage= (count*100)/df.shape[0]
percentage.round(2)
# Out:
# np.float64(48.65)

# %%
table = pd.crosstab([df['toss_decision'],df['toss_winner']],df['match_winner'])
table.head()
# Out:
# match_winner               Banglore  Chennai  Delhi  Gujarat  Hyderabad  \
# toss_decision toss_winner
# Bat           Banglore            1        0      0        1          0
#               Chennai             0        0      0        1          0
#               Gujarat             1        0      0        2          0
#               Hyderabad           0        0      0        0          0
#               Kolkata             0        0      0        0          0
#
# match_winner               Kolkata  Lucknow  Mumbai  Punjab  Rajasthan
# toss_decision toss_winner
# Bat           Banglore           0        0       0       0          0
#               Chennai            0        0       0       0          1
#               Gujarat            0        0       0       1          0
#               Hyderabad          0        0       0       1          0
#               Kolkata            1        0       0       0          0

# %%
sns.countplot(x = df['won_by'])
plt.title('Won By')
# Out:
# Text(0.5, 1.0, 'Won By')

# %% [markdown]
# ### **Key Player Performance**

# %% [markdown]
# 1. Most 'Player of the Match' award

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
count2 = df['player_of_the_match'].value_counts().head(10)
count2
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(x=count2.values,y=count2.index,palette='mako')
plt.title('Man of the Match')
# Out:
# Text(0.5, 1.0, 'Man of the Match')

# %% [markdown]
# 2. Top 2 Scorers

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.groupby(by='top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %% [markdown]
# 3. Top 10 Best bowling figures

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x: x.split('--')[0])

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
df['highest_wickets'] = df['highest_wickets'].astype(int)

# %%
top_bowlers = df.groupby(by='best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers
# Out:
# best_bowling
# Yuzvendra Chahal     17
# Jasprit Bumrah       11
# Kuldeep Yadav        11
# Rashid Khan          11
# Josh Hazlewood       10
# Kagiso Rabada        10
# Avesh Khan           10
# Umran Malik           9
# Wanindu Hasaranga     9
# T Natarajan           8
# Name: highest_wickets, dtype: int64

# %%
sns.barplot(x=top_bowlers.values,y=top_bowlers.index,palette='icefire')
plt.title('Top Bowlers')
# Out:
# Text(0.5, 1.0, 'Top Bowlers')

# %% [markdown]
# ### **Venue Analysis**

# %%
venue_count = df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(x = venue_count.values, y = venue_count.index, palette='cubehelix')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# Q1. Who won the highest margin by runs?

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
df[df['won_by'] == 'Runs'].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# Q2.Which player had the highest individual score?

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q3. Which bowler had the best bowling figures?

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
